# %%
# Instala versão do kafka para Python 3.11+
# %pip install kafka-python-ng boto3 pillow --quiet

from kafka import KafkaConsumer
import json, time, boto3
from datetime import datetime
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# Configura o cliente do MinIO (Simulando o AWS S3)
s3_client = boto3.client(
    's3',
    endpoint_url='http://minio:9000',
    aws_access_key_id='root-minio',
    aws_secret_access_key='root12345678',
    region_name='local'
)

consumer = KafkaConsumer(
    'cdc.public.transacoes_financeiras',
    bootstrap_servers=['kafka:29092'],
    auto_offset_reset='earliest',
    enable_auto_commit=False,
    group_id='grupo-consumer-v5',
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))
)

print("Conexões estabelecidas! Pronto para consumir...")
# Out:
# Conexões estabelecidas! Pronto para consumir...

# %%
buffer = []
ULTIMO_FLUSH = time.time()

for msg in consumer:
    envelope = msg.value
    payload = envelope.get('payload', envelope)
    operacao = payload.get('op')
    
    print(f"MSG recebida | offset={msg.offset} | op={operacao}")  # debug
    
    if operacao in ['c', 'u', 'r']:
        dados_tx = payload.get('after')
        if dados_tx:
            dados_tx['tipo_operacao_cdc'] = 'SNAPSHOT' if operacao == 'r' else 'INSERT' if operacao == 'c' else 'UPDATE'
            buffer.append(dados_tx)
    elif operacao == 'd':
        dados_tx = payload.get('before')
        if not dados_tx:
            dados_tx = payload.get('after') or {}
        dados_tx['tipo_operacao_cdc'] = 'AUDITORIA_DELETE'
        buffer.append(dados_tx)

    if len(buffer) >= 5 or (time.time() - ULTIMO_FLUSH >= 10 and len(buffer) > 0):
        
        timestamp_str = datetime.now().strftime("%Y%m%d-%H%M%S")
        nome_arquivo = f"streaming/financeiro/tx_batch_{timestamp_str}.jsonl"
        
        conteudo_jsonl = "\n".join([json.dumps(m) for m in buffer])
        s3_client.put_object(Bucket="raw", Key=nome_arquivo, Body=conteudo_jsonl.encode('utf-8'))
        consumer.commit() 
        
        print(f"[FLUSH] {len(buffer)} registros → {nome_arquivo}")
        
        buffer.clear()
        ULTIMO_FLUSH = time.time()
# Out:
# MSG recebida | offset=0 | op=r
# MSG recebida | offset=1 | op=r
# MSG recebida | offset=2 | op=r
# MSG recebida | offset=3 | op=r
# MSG recebida | offset=4 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=5 | op=r
# MSG recebida | offset=6 | op=r
# MSG recebida | offset=7 | op=r
# MSG recebida | offset=8 | op=r
# MSG recebida | offset=9 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=10 | op=r
# MSG recebida | offset=11 | op=r
# MSG recebida | offset=12 | op=r
# MSG recebida | offset=13 | op=r
# MSG recebida | offset=14 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=15 | op=r
# MSG recebida | offset=16 | op=r
# MSG recebida | offset=17 | op=r
# MSG recebida | offset=18 | op=r
# MSG recebida | offset=19 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=20 | op=r
# MSG recebida | offset=21 | op=r
# MSG recebida | offset=22 | op=r
# MSG recebida | offset=23 | op=r
# MSG recebida | offset=24 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=25 | op=r
# MSG recebida | offset=26 | op=r
# MSG recebida | offset=27 | op=r
# MSG recebida | offset=28 | op=r
# MSG recebida | offset=29 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=30 | op=r
# MSG recebida | offset=31 | op=r
# MSG recebida | offset=32 | op=r
# MSG recebida | offset=33 | op=r
# MSG recebida | offset=34 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=35 | op=r
# MSG recebida | offset=36 | op=r
# MSG recebida | offset=37 | op=r
# MSG recebida | offset=38 | op=r
# MSG recebida | offset=39 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=40 | op=r
# MSG recebida | offset=41 | op=r
# MSG recebida | offset=42 | op=r
# MSG recebida | offset=43 | op=r
# MSG recebida | offset=44 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=45 | op=r
# MSG recebida | offset=46 | op=r
# MSG recebida | offset=47 | op=r
# MSG recebida | offset=48 | op=r
# MSG recebida | offset=49 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=50 | op=r
# MSG recebida | offset=51 | op=r
# MSG recebida | offset=52 | op=r
# MSG recebida | offset=53 | op=r
# MSG recebida | offset=54 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=55 | op=r
# MSG recebida | offset=56 | op=r
# MSG recebida | offset=57 | op=r
# MSG recebida | offset=58 | op=r
# MSG recebida | offset=59 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=60 | op=r
# MSG recebida | offset=61 | op=r
# MSG recebida | offset=62 | op=r
# MSG recebida | offset=63 | op=r
# MSG recebida | offset=64 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=65 | op=r
# MSG recebida | offset=66 | op=r
# MSG recebida | offset=67 | op=r
# MSG recebida | offset=68 | op=r
# MSG recebida | offset=69 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=70 | op=r
# MSG recebida | offset=71 | op=r
# MSG recebida | offset=72 | op=r
# MSG recebida | offset=73 | op=r
# MSG recebida | offset=74 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=75 | op=r
# MSG recebida | offset=76 | op=r
# MSG recebida | offset=77 | op=r
# MSG recebida | offset=78 | op=r
# MSG recebida | offset=79 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=80 | op=r
# MSG recebida | offset=81 | op=r
# MSG recebida | offset=82 | op=r
# MSG recebida | offset=83 | op=r
# MSG recebida | offset=84 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=85 | op=r
# MSG recebida | offset=86 | op=r
# MSG recebida | offset=87 | op=r
# MSG recebida | offset=88 | op=r
# MSG recebida | offset=89 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=90 | op=r
# MSG recebida | offset=91 | op=r
# MSG recebida | offset=92 | op=r
# MSG recebida | offset=93 | op=r
# MSG recebida | offset=94 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=95 | op=r
# MSG recebida | offset=96 | op=r
# MSG recebida | offset=97 | op=r
# MSG recebida | offset=98 | op=r
# MSG recebida | offset=99 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=100 | op=r
# MSG recebida | offset=101 | op=r
# MSG recebida | offset=102 | op=r
# MSG recebida | offset=103 | op=r
# MSG recebida | offset=104 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=105 | op=r
# MSG recebida | offset=106 | op=r
# MSG recebida | offset=107 | op=r
# MSG recebida | offset=108 | op=r
# MSG recebida | offset=109 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=110 | op=r
# MSG recebida | offset=111 | op=r
# MSG recebida | offset=112 | op=r
# MSG recebida | offset=113 | op=r
# MSG recebida | offset=114 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=115 | op=r
# MSG recebida | offset=116 | op=r
# MSG recebida | offset=117 | op=r
# MSG recebida | offset=118 | op=r
# MSG recebida | offset=119 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=120 | op=r
# MSG recebida | offset=121 | op=r
# MSG recebida | offset=122 | op=r
# MSG recebida | offset=123 | op=r
# MSG recebida | offset=124 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=125 | op=r
# MSG recebida | offset=126 | op=r
# MSG recebida | offset=127 | op=r
# MSG recebida | offset=128 | op=r
# MSG recebida | offset=129 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=130 | op=r
# MSG recebida | offset=131 | op=r
# MSG recebida | offset=132 | op=r
# MSG recebida | offset=133 | op=r
# MSG recebida | offset=134 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=135 | op=r
# MSG recebida | offset=136 | op=r
# MSG recebida | offset=137 | op=r
# MSG recebida | offset=138 | op=r
# MSG recebida | offset=139 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=140 | op=r
# MSG recebida | offset=141 | op=r
# MSG recebida | offset=142 | op=r
# MSG recebida | offset=143 | op=r
# MSG recebida | offset=144 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=145 | op=r
# MSG recebida | offset=146 | op=r
# MSG recebida | offset=147 | op=r
# MSG recebida | offset=148 | op=r
# MSG recebida | offset=149 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=150 | op=r
# MSG recebida | offset=151 | op=r
# MSG recebida | offset=152 | op=r
# MSG recebida | offset=153 | op=r
# MSG recebida | offset=154 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=155 | op=r
# MSG recebida | offset=156 | op=r
# MSG recebida | offset=157 | op=r
# MSG recebida | offset=158 | op=r
# MSG recebida | offset=159 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=160 | op=r
# MSG recebida | offset=161 | op=r
# MSG recebida | offset=162 | op=r
# MSG recebida | offset=163 | op=r
# MSG recebida | offset=164 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=165 | op=r
# MSG recebida | offset=166 | op=r
# MSG recebida | offset=167 | op=r
# MSG recebida | offset=168 | op=r
# MSG recebida | offset=169 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=170 | op=r
# MSG recebida | offset=171 | op=r
# MSG recebida | offset=172 | op=r
# MSG recebida | offset=173 | op=r
# MSG recebida | offset=174 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=175 | op=r
# MSG recebida | offset=176 | op=r
# MSG recebida | offset=177 | op=r
# MSG recebida | offset=178 | op=r
# MSG recebida | offset=179 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=180 | op=r
# MSG recebida | offset=181 | op=r
# MSG recebida | offset=182 | op=r
# MSG recebida | offset=183 | op=r
# MSG recebida | offset=184 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=185 | op=r
# MSG recebida | offset=186 | op=r
# MSG recebida | offset=187 | op=r
# MSG recebida | offset=188 | op=r
# MSG recebida | offset=189 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=190 | op=r
# MSG recebida | offset=191 | op=r
# MSG recebida | offset=192 | op=r
# MSG recebida | offset=193 | op=r
# MSG recebida | offset=194 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=195 | op=r
# MSG recebida | offset=196 | op=r
# MSG recebida | offset=197 | op=r
# MSG recebida | offset=198 | op=r
# MSG recebida | offset=199 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=200 | op=r
# MSG recebida | offset=201 | op=r
# MSG recebida | offset=202 | op=r
# MSG recebida | offset=203 | op=r
# MSG recebida | offset=204 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=205 | op=r
# MSG recebida | offset=206 | op=r
# MSG recebida | offset=207 | op=r
# MSG recebida | offset=208 | op=r
# MSG recebida | offset=209 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=210 | op=r
# MSG recebida | offset=211 | op=r
# MSG recebida | offset=212 | op=r
# MSG recebida | offset=213 | op=r
# MSG recebida | offset=214 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=215 | op=r
# MSG recebida | offset=216 | op=r
# MSG recebida | offset=217 | op=r
# MSG recebida | offset=218 | op=r
# MSG recebida | offset=219 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=220 | op=r
# MSG recebida | offset=221 | op=r
# MSG recebida | offset=222 | op=r
# MSG recebida | offset=223 | op=r
# MSG recebida | offset=224 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=225 | op=r
# MSG recebida | offset=226 | op=r
# MSG recebida | offset=227 | op=r
# MSG recebida | offset=228 | op=r
# MSG recebida | offset=229 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=230 | op=r
# MSG recebida | offset=231 | op=r
# MSG recebida | offset=232 | op=r
# MSG recebida | offset=233 | op=r
# MSG recebida | offset=234 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=235 | op=r
# MSG recebida | offset=236 | op=r
# MSG recebida | offset=237 | op=r
# MSG recebida | offset=238 | op=r
# MSG recebida | offset=239 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=240 | op=r
# MSG recebida | offset=241 | op=r
# MSG recebida | offset=242 | op=r
# MSG recebida | offset=243 | op=r
# MSG recebida | offset=244 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=245 | op=r
# MSG recebida | offset=246 | op=r
# MSG recebida | offset=247 | op=r
# MSG recebida | offset=248 | op=r
# MSG recebida | offset=249 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=250 | op=r
# MSG recebida | offset=251 | op=r
# MSG recebida | offset=252 | op=r
# MSG recebida | offset=253 | op=r
# MSG recebida | offset=254 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=255 | op=r
# MSG recebida | offset=256 | op=r
# MSG recebida | offset=257 | op=r
# MSG recebida | offset=258 | op=r
# MSG recebida | offset=259 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=260 | op=r
# MSG recebida | offset=261 | op=r
# MSG recebida | offset=262 | op=r
# MSG recebida | offset=263 | op=r
# MSG recebida | offset=264 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=265 | op=r
# MSG recebida | offset=266 | op=r
# MSG recebida | offset=267 | op=r
# MSG recebida | offset=268 | op=r
# MSG recebida | offset=269 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=270 | op=r
# MSG recebida | offset=271 | op=r
# MSG recebida | offset=272 | op=r
# MSG recebida | offset=273 | op=r
# MSG recebida | offset=274 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=275 | op=r
# MSG recebida | offset=276 | op=r
# MSG recebida | offset=277 | op=r
# MSG recebida | offset=278 | op=r
# MSG recebida | offset=279 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=280 | op=r
# MSG recebida | offset=281 | op=r
# MSG recebida | offset=282 | op=r
# MSG recebida | offset=283 | op=r
# MSG recebida | offset=284 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=285 | op=r
# MSG recebida | offset=286 | op=r
# MSG recebida | offset=287 | op=r
# MSG recebida | offset=288 | op=r
# MSG recebida | offset=289 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=290 | op=r
# MSG recebida | offset=291 | op=r
# MSG recebida | offset=292 | op=r
# MSG recebida | offset=293 | op=r
# MSG recebida | offset=294 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=295 | op=r
# MSG recebida | offset=296 | op=r
# MSG recebida | offset=297 | op=r
# MSG recebida | offset=298 | op=r
# MSG recebida | offset=299 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=300 | op=r
# MSG recebida | offset=301 | op=r
# MSG recebida | offset=302 | op=r
# MSG recebida | offset=303 | op=r
# MSG recebida | offset=304 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=305 | op=r
# MSG recebida | offset=306 | op=r
# MSG recebida | offset=307 | op=r
# MSG recebida | offset=308 | op=r
# MSG recebida | offset=309 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=310 | op=r
# MSG recebida | offset=311 | op=r
# MSG recebida | offset=312 | op=r
# MSG recebida | offset=313 | op=r
# MSG recebida | offset=314 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=315 | op=r
# MSG recebida | offset=316 | op=r
# MSG recebida | offset=317 | op=r
# MSG recebida | offset=318 | op=r
# MSG recebida | offset=319 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=320 | op=r
# MSG recebida | offset=321 | op=r
# MSG recebida | offset=322 | op=r
# MSG recebida | offset=323 | op=r
# MSG recebida | offset=324 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=325 | op=r
# MSG recebida | offset=326 | op=r
# MSG recebida | offset=327 | op=r
# MSG recebida | offset=328 | op=r
# MSG recebida | offset=329 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=330 | op=r
# MSG recebida | offset=331 | op=r
# MSG recebida | offset=332 | op=r
# MSG recebida | offset=333 | op=r
# MSG recebida | offset=334 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=335 | op=r
# MSG recebida | offset=336 | op=r
# MSG recebida | offset=337 | op=r
# MSG recebida | offset=338 | op=r
# MSG recebida | offset=339 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=340 | op=r
# MSG recebida | offset=341 | op=r
# MSG recebida | offset=342 | op=r
# MSG recebida | offset=343 | op=r
# MSG recebida | offset=344 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=345 | op=r
# MSG recebida | offset=346 | op=r
# MSG recebida | offset=347 | op=r
# MSG recebida | offset=348 | op=r
# MSG recebida | offset=349 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=350 | op=r
# MSG recebida | offset=351 | op=r
# MSG recebida | offset=352 | op=r
# MSG recebida | offset=353 | op=r
# MSG recebida | offset=354 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=355 | op=r
# MSG recebida | offset=356 | op=r
# MSG recebida | offset=357 | op=r
# MSG recebida | offset=358 | op=r
# MSG recebida | offset=359 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=360 | op=r
# MSG recebida | offset=361 | op=r
# MSG recebida | offset=362 | op=r
# MSG recebida | offset=363 | op=r
# MSG recebida | offset=364 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=365 | op=r
# MSG recebida | offset=366 | op=r
# MSG recebida | offset=367 | op=r
# MSG recebida | offset=368 | op=r
# MSG recebida | offset=369 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=370 | op=r
# MSG recebida | offset=371 | op=r
# MSG recebida | offset=372 | op=r
# MSG recebida | offset=373 | op=r
# MSG recebida | offset=374 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=375 | op=r
# MSG recebida | offset=376 | op=r
# MSG recebida | offset=377 | op=r
# MSG recebida | offset=378 | op=r
# MSG recebida | offset=379 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=380 | op=r
# MSG recebida | offset=381 | op=r
# MSG recebida | offset=382 | op=r
# MSG recebida | offset=383 | op=r
# MSG recebida | offset=384 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=385 | op=r
# MSG recebida | offset=386 | op=r
# MSG recebida | offset=387 | op=r
# MSG recebida | offset=388 | op=r
# MSG recebida | offset=389 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=390 | op=r
# MSG recebida | offset=391 | op=r
# MSG recebida | offset=392 | op=r
# MSG recebida | offset=393 | op=r
# MSG recebida | offset=394 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=395 | op=r
# MSG recebida | offset=396 | op=r
# MSG recebida | offset=397 | op=r
# MSG recebida | offset=398 | op=r
# MSG recebida | offset=399 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=400 | op=r
# MSG recebida | offset=401 | op=r
# MSG recebida | offset=402 | op=r
# MSG recebida | offset=403 | op=r
# MSG recebida | offset=404 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=405 | op=r
# MSG recebida | offset=406 | op=r
# MSG recebida | offset=407 | op=r
# MSG recebida | offset=408 | op=r
# MSG recebida | offset=409 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=410 | op=r
# MSG recebida | offset=411 | op=r
# MSG recebida | offset=412 | op=r
# MSG recebida | offset=413 | op=r
# MSG recebida | offset=414 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=415 | op=r
# MSG recebida | offset=416 | op=r
# MSG recebida | offset=417 | op=r
# MSG recebida | offset=418 | op=r
# MSG recebida | offset=419 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=420 | op=r
# MSG recebida | offset=421 | op=r
# MSG recebida | offset=422 | op=r
# MSG recebida | offset=423 | op=r
# MSG recebida | offset=424 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=425 | op=r
# MSG recebida | offset=426 | op=r
# MSG recebida | offset=427 | op=r
# MSG recebida | offset=428 | op=r
# MSG recebida | offset=429 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=430 | op=r
# MSG recebida | offset=431 | op=r
# MSG recebida | offset=432 | op=r
# MSG recebida | offset=433 | op=r
# MSG recebida | offset=434 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=435 | op=r
# MSG recebida | offset=436 | op=r
# MSG recebida | offset=437 | op=r
# MSG recebida | offset=438 | op=r
# MSG recebida | offset=439 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=440 | op=r
# MSG recebida | offset=441 | op=r
# MSG recebida | offset=442 | op=r
# MSG recebida | offset=443 | op=r
# MSG recebida | offset=444 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=445 | op=r
# MSG recebida | offset=446 | op=r
# MSG recebida | offset=447 | op=r
# MSG recebida | offset=448 | op=r
# MSG recebida | offset=449 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=450 | op=r
# MSG recebida | offset=451 | op=r
# MSG recebida | offset=452 | op=r
# MSG recebida | offset=453 | op=r
# MSG recebida | offset=454 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=455 | op=r
# MSG recebida | offset=456 | op=r
# MSG recebida | offset=457 | op=r
# MSG recebida | offset=458 | op=r
# MSG recebida | offset=459 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=460 | op=r
# MSG recebida | offset=461 | op=r
# MSG recebida | offset=462 | op=r
# MSG recebida | offset=463 | op=r
# MSG recebida | offset=464 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=465 | op=r
# MSG recebida | offset=466 | op=r
# MSG recebida | offset=467 | op=r
# MSG recebida | offset=468 | op=r
# MSG recebida | offset=469 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=470 | op=r
# MSG recebida | offset=471 | op=r
# MSG recebida | offset=472 | op=r
# MSG recebida | offset=473 | op=r
# MSG recebida | offset=474 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=475 | op=r
# MSG recebida | offset=476 | op=r
# MSG recebida | offset=477 | op=r
# MSG recebida | offset=478 | op=r
# MSG recebida | offset=479 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=480 | op=r
# MSG recebida | offset=481 | op=r
# MSG recebida | offset=482 | op=r
# MSG recebida | offset=483 | op=r
# MSG recebida | offset=484 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=485 | op=r
# MSG recebida | offset=486 | op=r
# MSG recebida | offset=487 | op=r
# MSG recebida | offset=488 | op=r
# MSG recebida | offset=489 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=490 | op=r
# MSG recebida | offset=491 | op=r
# MSG recebida | offset=492 | op=r
# MSG recebida | offset=493 | op=r
# MSG recebida | offset=494 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=495 | op=r
# MSG recebida | offset=496 | op=r
# MSG recebida | offset=497 | op=r
# MSG recebida | offset=498 | op=r
# MSG recebida | offset=499 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=500 | op=r
# MSG recebida | offset=501 | op=r
# MSG recebida | offset=502 | op=r
# MSG recebida | offset=503 | op=r
# MSG recebida | offset=504 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=505 | op=r
# MSG recebida | offset=506 | op=r
# MSG recebida | offset=507 | op=r
# MSG recebida | offset=508 | op=r
# MSG recebida | offset=509 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=510 | op=r
# MSG recebida | offset=511 | op=r
# MSG recebida | offset=512 | op=r
# MSG recebida | offset=513 | op=r
# MSG recebida | offset=514 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=515 | op=r
# MSG recebida | offset=516 | op=r
# MSG recebida | offset=517 | op=r
# MSG recebida | offset=518 | op=r
# MSG recebida | offset=519 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=520 | op=r
# MSG recebida | offset=521 | op=r
# MSG recebida | offset=522 | op=r
# MSG recebida | offset=523 | op=r
# MSG recebida | offset=524 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=525 | op=r
# MSG recebida | offset=526 | op=r
# MSG recebida | offset=527 | op=r
# MSG recebida | offset=528 | op=r
# MSG recebida | offset=529 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=530 | op=r
# MSG recebida | offset=531 | op=r
# MSG recebida | offset=532 | op=r
# MSG recebida | offset=533 | op=r
# MSG recebida | offset=534 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=535 | op=r
# MSG recebida | offset=536 | op=r
# MSG recebida | offset=537 | op=r
# MSG recebida | offset=538 | op=r
# MSG recebida | offset=539 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=540 | op=r
# MSG recebida | offset=541 | op=r
# MSG recebida | offset=542 | op=r
# MSG recebida | offset=543 | op=r
# MSG recebida | offset=544 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=545 | op=r
# MSG recebida | offset=546 | op=r
# MSG recebida | offset=547 | op=r
# MSG recebida | offset=548 | op=r
# MSG recebida | offset=549 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=550 | op=r
# MSG recebida | offset=551 | op=r
# MSG recebida | offset=552 | op=r
# MSG recebida | offset=553 | op=r
# MSG recebida | offset=554 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=555 | op=r
# MSG recebida | offset=556 | op=r
# MSG recebida | offset=557 | op=r
# MSG recebida | offset=558 | op=r
# MSG recebida | offset=559 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=560 | op=r
# MSG recebida | offset=561 | op=r
# MSG recebida | offset=562 | op=r
# MSG recebida | offset=563 | op=r
# MSG recebida | offset=564 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=565 | op=r
# MSG recebida | offset=566 | op=r
# MSG recebida | offset=567 | op=r
# MSG recebida | offset=568 | op=r
# MSG recebida | offset=569 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=570 | op=r
# MSG recebida | offset=571 | op=r
# MSG recebida | offset=572 | op=r
# MSG recebida | offset=573 | op=r
# MSG recebida | offset=574 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=575 | op=r
# MSG recebida | offset=576 | op=r
# MSG recebida | offset=577 | op=r
# MSG recebida | offset=578 | op=r
# MSG recebida | offset=579 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=580 | op=r
# MSG recebida | offset=581 | op=r
# MSG recebida | offset=582 | op=r
# MSG recebida | offset=583 | op=r
# MSG recebida | offset=584 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143010.jsonl
# MSG recebida | offset=585 | op=r
# MSG recebida | offset=586 | op=r
# MSG recebida | offset=587 | op=r
# MSG recebida | offset=588 | op=r
# MSG recebida | offset=589 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=590 | op=r
# MSG recebida | offset=591 | op=r
# MSG recebida | offset=592 | op=r
# MSG recebida | offset=593 | op=r
# MSG recebida | offset=594 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=595 | op=r
# MSG recebida | offset=596 | op=r
# MSG recebida | offset=597 | op=r
# MSG recebida | offset=598 | op=r
# MSG recebida | offset=599 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=600 | op=r
# MSG recebida | offset=601 | op=r
# MSG recebida | offset=602 | op=r
# MSG recebida | offset=603 | op=r
# MSG recebida | offset=604 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=605 | op=r
# MSG recebida | offset=606 | op=r
# MSG recebida | offset=607 | op=r
# MSG recebida | offset=608 | op=r
# MSG recebida | offset=609 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=610 | op=r
# MSG recebida | offset=611 | op=r
# MSG recebida | offset=612 | op=r
# MSG recebida | offset=613 | op=r
# MSG recebida | offset=614 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=615 | op=r
# MSG recebida | offset=616 | op=r
# MSG recebida | offset=617 | op=r
# MSG recebida | offset=618 | op=r
# MSG recebida | offset=619 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=620 | op=r
# MSG recebida | offset=621 | op=r
# MSG recebida | offset=622 | op=r
# MSG recebida | offset=623 | op=r
# MSG recebida | offset=624 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=625 | op=r
# MSG recebida | offset=626 | op=r
# MSG recebida | offset=627 | op=r
# MSG recebida | offset=628 | op=r
# MSG recebida | offset=629 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=630 | op=r
# MSG recebida | offset=631 | op=r
# MSG recebida | offset=632 | op=r
# MSG recebida | offset=633 | op=r
# MSG recebida | offset=634 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=635 | op=r
# MSG recebida | offset=636 | op=r
# MSG recebida | offset=637 | op=r
# MSG recebida | offset=638 | op=r
# MSG recebida | offset=639 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=640 | op=r
# MSG recebida | offset=641 | op=r
# MSG recebida | offset=642 | op=r
# MSG recebida | offset=643 | op=r
# MSG recebida | offset=644 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=645 | op=r
# MSG recebida | offset=646 | op=r
# MSG recebida | offset=647 | op=r
# MSG recebida | offset=648 | op=r
# MSG recebida | offset=649 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=650 | op=r
# MSG recebida | offset=651 | op=r
# MSG recebida | offset=652 | op=r
# MSG recebida | offset=653 | op=r
# MSG recebida | offset=654 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=655 | op=r
# MSG recebida | offset=656 | op=r
# MSG recebida | offset=657 | op=r
# MSG recebida | offset=658 | op=r
# MSG recebida | offset=659 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=660 | op=r
# MSG recebida | offset=661 | op=r
# MSG recebida | offset=662 | op=r
# MSG recebida | offset=663 | op=r
# MSG recebida | offset=664 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=665 | op=r
# MSG recebida | offset=666 | op=r
# MSG recebida | offset=667 | op=r
# MSG recebida | offset=668 | op=r
# MSG recebida | offset=669 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=670 | op=r
# MSG recebida | offset=671 | op=r
# MSG recebida | offset=672 | op=r
# MSG recebida | offset=673 | op=r
# MSG recebida | offset=674 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=675 | op=r
# MSG recebida | offset=676 | op=r
# MSG recebida | offset=677 | op=r
# MSG recebida | offset=678 | op=r
# MSG recebida | offset=679 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=680 | op=r
# MSG recebida | offset=681 | op=r
# MSG recebida | offset=682 | op=r
# MSG recebida | offset=683 | op=r
# MSG recebida | offset=684 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=685 | op=r
# MSG recebida | offset=686 | op=r
# MSG recebida | offset=687 | op=r
# MSG recebida | offset=688 | op=r
# MSG recebida | offset=689 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=690 | op=r
# MSG recebida | offset=691 | op=r
# MSG recebida | offset=692 | op=r
# MSG recebida | offset=693 | op=r
# MSG recebida | offset=694 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=695 | op=r
# MSG recebida | offset=696 | op=r
# MSG recebida | offset=697 | op=r
# MSG recebida | offset=698 | op=r
# MSG recebida | offset=699 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=700 | op=r
# MSG recebida | offset=701 | op=r
# MSG recebida | offset=702 | op=r
# MSG recebida | offset=703 | op=r
# MSG recebida | offset=704 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=705 | op=r
# MSG recebida | offset=706 | op=r
# MSG recebida | offset=707 | op=r
# MSG recebida | offset=708 | op=r
# MSG recebida | offset=709 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=710 | op=r
# MSG recebida | offset=711 | op=r
# MSG recebida | offset=712 | op=r
# MSG recebida | offset=713 | op=r
# MSG recebida | offset=714 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=715 | op=r
# MSG recebida | offset=716 | op=r
# MSG recebida | offset=717 | op=r
# MSG recebida | offset=718 | op=r
# MSG recebida | offset=719 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=720 | op=r
# MSG recebida | offset=721 | op=r
# MSG recebida | offset=722 | op=r
# MSG recebida | offset=723 | op=r
# MSG recebida | offset=724 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=725 | op=r
# MSG recebida | offset=726 | op=r
# MSG recebida | offset=727 | op=r
# MSG recebida | offset=728 | op=r
# MSG recebida | offset=729 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=730 | op=r
# MSG recebida | offset=731 | op=r
# MSG recebida | offset=732 | op=r
# MSG recebida | offset=733 | op=r
# MSG recebida | offset=734 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=735 | op=r
# MSG recebida | offset=736 | op=r
# MSG recebida | offset=737 | op=r
# MSG recebida | offset=738 | op=r
# MSG recebida | offset=739 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=740 | op=r
# MSG recebida | offset=741 | op=r
# MSG recebida | offset=742 | op=r
# MSG recebida | offset=743 | op=r
# MSG recebida | offset=744 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=745 | op=r
# MSG recebida | offset=746 | op=r
# MSG recebida | offset=747 | op=r
# MSG recebida | offset=748 | op=r
# MSG recebida | offset=749 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=750 | op=r
# MSG recebida | offset=751 | op=r
# MSG recebida | offset=752 | op=r
# MSG recebida | offset=753 | op=r
# MSG recebida | offset=754 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=755 | op=r
# MSG recebida | offset=756 | op=r
# MSG recebida | offset=757 | op=r
# MSG recebida | offset=758 | op=r
# MSG recebida | offset=759 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=760 | op=r
# MSG recebida | offset=761 | op=r
# MSG recebida | offset=762 | op=r
# MSG recebida | offset=763 | op=r
# MSG recebida | offset=764 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=765 | op=r
# MSG recebida | offset=766 | op=r
# MSG recebida | offset=767 | op=r
# MSG recebida | offset=768 | op=r
# MSG recebida | offset=769 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=770 | op=r
# MSG recebida | offset=771 | op=r
# MSG recebida | offset=772 | op=r
# MSG recebida | offset=773 | op=r
# MSG recebida | offset=774 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=775 | op=r
# MSG recebida | offset=776 | op=r
# MSG recebida | offset=777 | op=r
# MSG recebida | offset=778 | op=r
# MSG recebida | offset=779 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=780 | op=r
# MSG recebida | offset=781 | op=r
# MSG recebida | offset=782 | op=r
# MSG recebida | offset=783 | op=r
# MSG recebida | offset=784 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=785 | op=r
# MSG recebida | offset=786 | op=r
# MSG recebida | offset=787 | op=r
# MSG recebida | offset=788 | op=r
# MSG recebida | offset=789 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=790 | op=r
# MSG recebida | offset=791 | op=r
# MSG recebida | offset=792 | op=r
# MSG recebida | offset=793 | op=r
# MSG recebida | offset=794 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=795 | op=r
# MSG recebida | offset=796 | op=r
# MSG recebida | offset=797 | op=r
# MSG recebida | offset=798 | op=r
# MSG recebida | offset=799 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=800 | op=r
# MSG recebida | offset=801 | op=r
# MSG recebida | offset=802 | op=r
# MSG recebida | offset=803 | op=r
# MSG recebida | offset=804 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=805 | op=r
# MSG recebida | offset=806 | op=r
# MSG recebida | offset=807 | op=r
# MSG recebida | offset=808 | op=r
# MSG recebida | offset=809 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=810 | op=r
# MSG recebida | offset=811 | op=r
# MSG recebida | offset=812 | op=r
# MSG recebida | offset=813 | op=r
# MSG recebida | offset=814 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=815 | op=r
# MSG recebida | offset=816 | op=r
# MSG recebida | offset=817 | op=r
# MSG recebida | offset=818 | op=r
# MSG recebida | offset=819 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=820 | op=r
# MSG recebida | offset=821 | op=r
# MSG recebida | offset=822 | op=r
# MSG recebida | offset=823 | op=r
# MSG recebida | offset=824 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=825 | op=r
# MSG recebida | offset=826 | op=r
# MSG recebida | offset=827 | op=r
# MSG recebida | offset=828 | op=r
# MSG recebida | offset=829 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=830 | op=r
# MSG recebida | offset=831 | op=r
# MSG recebida | offset=832 | op=r
# MSG recebida | offset=833 | op=r
# MSG recebida | offset=834 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=835 | op=r
# MSG recebida | offset=836 | op=r
# MSG recebida | offset=837 | op=r
# MSG recebida | offset=838 | op=r
# MSG recebida | offset=839 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=840 | op=r
# MSG recebida | offset=841 | op=r
# MSG recebida | offset=842 | op=r
# MSG recebida | offset=843 | op=r
# MSG recebida | offset=844 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=845 | op=r
# MSG recebida | offset=846 | op=r
# MSG recebida | offset=847 | op=r
# MSG recebida | offset=848 | op=r
# MSG recebida | offset=849 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=850 | op=r
# MSG recebida | offset=851 | op=r
# MSG recebida | offset=852 | op=r
# MSG recebida | offset=853 | op=r
# MSG recebida | offset=854 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=855 | op=r
# MSG recebida | offset=856 | op=r
# MSG recebida | offset=857 | op=r
# MSG recebida | offset=858 | op=r
# MSG recebida | offset=859 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=860 | op=r
# MSG recebida | offset=861 | op=r
# MSG recebida | offset=862 | op=r
# MSG recebida | offset=863 | op=r
# MSG recebida | offset=864 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=865 | op=r
# MSG recebida | offset=866 | op=r
# MSG recebida | offset=867 | op=r
# MSG recebida | offset=868 | op=r
# MSG recebida | offset=869 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=870 | op=r
# MSG recebida | offset=871 | op=r
# MSG recebida | offset=872 | op=r
# MSG recebida | offset=873 | op=r
# MSG recebida | offset=874 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=875 | op=r
# MSG recebida | offset=876 | op=r
# MSG recebida | offset=877 | op=r
# MSG recebida | offset=878 | op=r
# MSG recebida | offset=879 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=880 | op=r
# MSG recebida | offset=881 | op=r
# MSG recebida | offset=882 | op=r
# MSG recebida | offset=883 | op=r
# MSG recebida | offset=884 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=885 | op=r
# MSG recebida | offset=886 | op=r
# MSG recebida | offset=887 | op=r
# MSG recebida | offset=888 | op=r
# MSG recebida | offset=889 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=890 | op=r
# MSG recebida | offset=891 | op=r
# MSG recebida | offset=892 | op=r
# MSG recebida | offset=893 | op=r
# MSG recebida | offset=894 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=895 | op=r
# MSG recebida | offset=896 | op=r
# MSG recebida | offset=897 | op=r
# MSG recebida | offset=898 | op=r
# MSG recebida | offset=899 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=900 | op=r
# MSG recebida | offset=901 | op=r
# MSG recebida | offset=902 | op=r
# MSG recebida | offset=903 | op=r
# MSG recebida | offset=904 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=905 | op=r
# MSG recebida | offset=906 | op=r
# MSG recebida | offset=907 | op=r
# MSG recebida | offset=908 | op=r
# MSG recebida | offset=909 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=910 | op=r
# MSG recebida | offset=911 | op=r
# MSG recebida | offset=912 | op=r
# MSG recebida | offset=913 | op=r
# MSG recebida | offset=914 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=915 | op=r
# MSG recebida | offset=916 | op=r
# MSG recebida | offset=917 | op=r
# MSG recebida | offset=918 | op=r
# MSG recebida | offset=919 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=920 | op=r
# MSG recebida | offset=921 | op=r
# MSG recebida | offset=922 | op=r
# MSG recebida | offset=923 | op=r
# MSG recebida | offset=924 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=925 | op=r
# MSG recebida | offset=926 | op=r
# MSG recebida | offset=927 | op=r
# MSG recebida | offset=928 | op=r
# MSG recebida | offset=929 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=930 | op=r
# MSG recebida | offset=931 | op=r
# MSG recebida | offset=932 | op=r
# MSG recebida | offset=933 | op=r
# MSG recebida | offset=934 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=935 | op=r
# MSG recebida | offset=936 | op=r
# MSG recebida | offset=937 | op=r
# MSG recebida | offset=938 | op=r
# MSG recebida | offset=939 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=940 | op=r
# MSG recebida | offset=941 | op=r
# MSG recebida | offset=942 | op=r
# MSG recebida | offset=943 | op=r
# MSG recebida | offset=944 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=945 | op=r
# MSG recebida | offset=946 | op=r
# MSG recebida | offset=947 | op=r
# MSG recebida | offset=948 | op=r
# MSG recebida | offset=949 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=950 | op=r
# MSG recebida | offset=951 | op=r
# MSG recebida | offset=952 | op=r
# MSG recebida | offset=953 | op=r
# MSG recebida | offset=954 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=955 | op=r
# MSG recebida | offset=956 | op=r
# MSG recebida | offset=957 | op=r
# MSG recebida | offset=958 | op=r
# MSG recebida | offset=959 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=960 | op=r
# MSG recebida | offset=961 | op=r
# MSG recebida | offset=962 | op=r
# MSG recebida | offset=963 | op=r
# MSG recebida | offset=964 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=965 | op=r
# MSG recebida | offset=966 | op=r
# MSG recebida | offset=967 | op=r
# MSG recebida | offset=968 | op=r
# MSG recebida | offset=969 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=970 | op=r
# MSG recebida | offset=971 | op=r
# MSG recebida | offset=972 | op=r
# MSG recebida | offset=973 | op=r
# MSG recebida | offset=974 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=975 | op=r
# MSG recebida | offset=976 | op=r
# MSG recebida | offset=977 | op=r
# MSG recebida | offset=978 | op=r
# MSG recebida | offset=979 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=980 | op=r
# MSG recebida | offset=981 | op=r
# MSG recebida | offset=982 | op=r
# MSG recebida | offset=983 | op=r
# MSG recebida | offset=984 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=985 | op=r
# MSG recebida | offset=986 | op=r
# MSG recebida | offset=987 | op=r
# MSG recebida | offset=988 | op=r
# MSG recebida | offset=989 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=990 | op=r
# MSG recebida | offset=991 | op=r
# MSG recebida | offset=992 | op=r
# MSG recebida | offset=993 | op=r
# MSG recebida | offset=994 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=995 | op=r
# MSG recebida | offset=996 | op=r
# MSG recebida | offset=997 | op=r
# MSG recebida | offset=998 | op=r
# MSG recebida | offset=999 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=1000 | op=r
# MSG recebida | offset=1001 | op=r
# MSG recebida | offset=1002 | op=r
# MSG recebida | offset=1003 | op=r
# MSG recebida | offset=1004 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143011.jsonl
# MSG recebida | offset=1005 | op=r
# ...
# MSG recebida | offset=19690 | op=r
# MSG recebida | offset=19691 | op=r
# MSG recebida | offset=19692 | op=r
# MSG recebida | offset=19693 | op=r
# MSG recebida | offset=19694 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143040.jsonl
# MSG recebida | offset=19695 | op=r
# MSG recebida | offset=19696 | op=r
# MSG recebida | offset=19697 | op=r
# MSG recebida | offset=19698 | op=r
# MSG recebida | offset=19699 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143040.jsonl
# MSG recebida | offset=19700 | op=r
# MSG recebida | offset=19701 | op=r
# MSG recebida | offset=19702 | op=r
# MSG recebida | offset=19703 | op=r
# MSG recebida | offset=19704 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143040.jsonl
# MSG recebida | offset=19705 | op=r
# MSG recebida | offset=19706 | op=r
# MSG recebida | offset=19707 | op=r
# MSG recebida | offset=19708 | op=r
# MSG recebida | offset=19709 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143040.jsonl
# MSG recebida | offset=19710 | op=r
# MSG recebida | offset=19711 | op=r
# MSG recebida | offset=19712 | op=r
# MSG recebida | offset=19713 | op=r
# MSG recebida | offset=19714 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143040.jsonl
# MSG recebida | offset=19715 | op=r
# MSG recebida | offset=19716 | op=r
# MSG recebida | offset=19717 | op=r
# MSG recebida | offset=19718 | op=r
# MSG recebida | offset=19719 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19720 | op=r
# MSG recebida | offset=19721 | op=r
# MSG recebida | offset=19722 | op=r
# MSG recebida | offset=19723 | op=r
# MSG recebida | offset=19724 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19725 | op=r
# MSG recebida | offset=19726 | op=r
# MSG recebida | offset=19727 | op=r
# MSG recebida | offset=19728 | op=r
# MSG recebida | offset=19729 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19730 | op=r
# MSG recebida | offset=19731 | op=r
# MSG recebida | offset=19732 | op=r
# MSG recebida | offset=19733 | op=r
# MSG recebida | offset=19734 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19735 | op=r
# MSG recebida | offset=19736 | op=r
# MSG recebida | offset=19737 | op=r
# MSG recebida | offset=19738 | op=r
# MSG recebida | offset=19739 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19740 | op=r
# MSG recebida | offset=19741 | op=r
# MSG recebida | offset=19742 | op=r
# MSG recebida | offset=19743 | op=r
# MSG recebida | offset=19744 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19745 | op=r
# MSG recebida | offset=19746 | op=r
# MSG recebida | offset=19747 | op=r
# MSG recebida | offset=19748 | op=r
# MSG recebida | offset=19749 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19750 | op=r
# MSG recebida | offset=19751 | op=r
# MSG recebida | offset=19752 | op=r
# MSG recebida | offset=19753 | op=r
# MSG recebida | offset=19754 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19755 | op=r
# MSG recebida | offset=19756 | op=r
# MSG recebida | offset=19757 | op=r
# MSG recebida | offset=19758 | op=r
# MSG recebida | offset=19759 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19760 | op=r
# MSG recebida | offset=19761 | op=r
# MSG recebida | offset=19762 | op=r
# MSG recebida | offset=19763 | op=r
# MSG recebida | offset=19764 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19765 | op=r
# MSG recebida | offset=19766 | op=r
# MSG recebida | offset=19767 | op=r
# MSG recebida | offset=19768 | op=r
# MSG recebida | offset=19769 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19770 | op=r
# MSG recebida | offset=19771 | op=r
# MSG recebida | offset=19772 | op=r
# MSG recebida | offset=19773 | op=r
# MSG recebida | offset=19774 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19775 | op=r
# MSG recebida | offset=19776 | op=r
# MSG recebida | offset=19777 | op=r
# MSG recebida | offset=19778 | op=r
# MSG recebida | offset=19779 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19780 | op=r
# MSG recebida | offset=19781 | op=r
# MSG recebida | offset=19782 | op=r
# MSG recebida | offset=19783 | op=r
# MSG recebida | offset=19784 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19785 | op=r
# MSG recebida | offset=19786 | op=r
# MSG recebida | offset=19787 | op=r
# MSG recebida | offset=19788 | op=r
# MSG recebida | offset=19789 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19790 | op=r
# MSG recebida | offset=19791 | op=r
# MSG recebida | offset=19792 | op=r
# MSG recebida | offset=19793 | op=r
# MSG recebida | offset=19794 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19795 | op=r
# MSG recebida | offset=19796 | op=r
# MSG recebida | offset=19797 | op=r
# MSG recebida | offset=19798 | op=r
# MSG recebida | offset=19799 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19800 | op=r
# MSG recebida | offset=19801 | op=r
# MSG recebida | offset=19802 | op=r
# MSG recebida | offset=19803 | op=r
# MSG recebida | offset=19804 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19805 | op=r
# MSG recebida | offset=19806 | op=r
# MSG recebida | offset=19807 | op=r
# MSG recebida | offset=19808 | op=r
# MSG recebida | offset=19809 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19810 | op=r
# MSG recebida | offset=19811 | op=r
# MSG recebida | offset=19812 | op=r
# MSG recebida | offset=19813 | op=r
# MSG recebida | offset=19814 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19815 | op=r
# MSG recebida | offset=19816 | op=r
# MSG recebida | offset=19817 | op=r
# MSG recebida | offset=19818 | op=r
# MSG recebida | offset=19819 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19820 | op=r
# MSG recebida | offset=19821 | op=r
# MSG recebida | offset=19822 | op=r
# MSG recebida | offset=19823 | op=r
# MSG recebida | offset=19824 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19825 | op=r
# MSG recebida | offset=19826 | op=r
# MSG recebida | offset=19827 | op=r
# MSG recebida | offset=19828 | op=r
# MSG recebida | offset=19829 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19830 | op=r
# MSG recebida | offset=19831 | op=r
# MSG recebida | offset=19832 | op=r
# MSG recebida | offset=19833 | op=r
# MSG recebida | offset=19834 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19835 | op=r
# MSG recebida | offset=19836 | op=r
# MSG recebida | offset=19837 | op=r
# MSG recebida | offset=19838 | op=r
# MSG recebida | offset=19839 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19840 | op=r
# MSG recebida | offset=19841 | op=r
# MSG recebida | offset=19842 | op=r
# MSG recebida | offset=19843 | op=r
# MSG recebida | offset=19844 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19845 | op=r
# MSG recebida | offset=19846 | op=r
# MSG recebida | offset=19847 | op=r
# MSG recebida | offset=19848 | op=r
# MSG recebida | offset=19849 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19850 | op=r
# MSG recebida | offset=19851 | op=r
# MSG recebida | offset=19852 | op=r
# MSG recebida | offset=19853 | op=r
# MSG recebida | offset=19854 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19855 | op=r
# MSG recebida | offset=19856 | op=r
# MSG recebida | offset=19857 | op=r
# MSG recebida | offset=19858 | op=r
# MSG recebida | offset=19859 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19860 | op=r
# MSG recebida | offset=19861 | op=r
# MSG recebida | offset=19862 | op=r
# MSG recebida | offset=19863 | op=r
# MSG recebida | offset=19864 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19865 | op=r
# MSG recebida | offset=19866 | op=r
# MSG recebida | offset=19867 | op=r
# MSG recebida | offset=19868 | op=r
# MSG recebida | offset=19869 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19870 | op=r
# MSG recebida | offset=19871 | op=r
# MSG recebida | offset=19872 | op=r
# MSG recebida | offset=19873 | op=r
# MSG recebida | offset=19874 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19875 | op=r
# MSG recebida | offset=19876 | op=r
# MSG recebida | offset=19877 | op=r
# MSG recebida | offset=19878 | op=r
# MSG recebida | offset=19879 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19880 | op=r
# MSG recebida | offset=19881 | op=r
# MSG recebida | offset=19882 | op=r
# MSG recebida | offset=19883 | op=r
# MSG recebida | offset=19884 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19885 | op=r
# MSG recebida | offset=19886 | op=r
# MSG recebida | offset=19887 | op=r
# MSG recebida | offset=19888 | op=r
# MSG recebida | offset=19889 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19890 | op=r
# MSG recebida | offset=19891 | op=r
# MSG recebida | offset=19892 | op=r
# MSG recebida | offset=19893 | op=r
# MSG recebida | offset=19894 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19895 | op=r
# MSG recebida | offset=19896 | op=r
# MSG recebida | offset=19897 | op=r
# MSG recebida | offset=19898 | op=r
# MSG recebida | offset=19899 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19900 | op=r
# MSG recebida | offset=19901 | op=r
# MSG recebida | offset=19902 | op=r
# MSG recebida | offset=19903 | op=r
# MSG recebida | offset=19904 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19905 | op=r
# MSG recebida | offset=19906 | op=r
# MSG recebida | offset=19907 | op=r
# MSG recebida | offset=19908 | op=r
# MSG recebida | offset=19909 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19910 | op=r
# MSG recebida | offset=19911 | op=r
# MSG recebida | offset=19912 | op=r
# MSG recebida | offset=19913 | op=r
# MSG recebida | offset=19914 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19915 | op=r
# MSG recebida | offset=19916 | op=r
# MSG recebida | offset=19917 | op=r
# MSG recebida | offset=19918 | op=r
# MSG recebida | offset=19919 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19920 | op=r
# MSG recebida | offset=19921 | op=r
# MSG recebida | offset=19922 | op=r
# MSG recebida | offset=19923 | op=r
# MSG recebida | offset=19924 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19925 | op=r
# MSG recebida | offset=19926 | op=r
# MSG recebida | offset=19927 | op=r
# MSG recebida | offset=19928 | op=r
# MSG recebida | offset=19929 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19930 | op=r
# MSG recebida | offset=19931 | op=r
# MSG recebida | offset=19932 | op=r
# MSG recebida | offset=19933 | op=r
# MSG recebida | offset=19934 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19935 | op=r
# MSG recebida | offset=19936 | op=r
# MSG recebida | offset=19937 | op=r
# MSG recebida | offset=19938 | op=r
# MSG recebida | offset=19939 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19940 | op=r
# MSG recebida | offset=19941 | op=r
# MSG recebida | offset=19942 | op=r
# MSG recebida | offset=19943 | op=r
# MSG recebida | offset=19944 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19945 | op=r
# MSG recebida | offset=19946 | op=r
# MSG recebida | offset=19947 | op=r
# MSG recebida | offset=19948 | op=r
# MSG recebida | offset=19949 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19950 | op=r
# MSG recebida | offset=19951 | op=r
# MSG recebida | offset=19952 | op=r
# MSG recebida | offset=19953 | op=r
# MSG recebida | offset=19954 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19955 | op=r
# MSG recebida | offset=19956 | op=r
# MSG recebida | offset=19957 | op=r
# MSG recebida | offset=19958 | op=r
# MSG recebida | offset=19959 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19960 | op=r
# MSG recebida | offset=19961 | op=r
# MSG recebida | offset=19962 | op=r
# MSG recebida | offset=19963 | op=r
# MSG recebida | offset=19964 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19965 | op=r
# MSG recebida | offset=19966 | op=r
# MSG recebida | offset=19967 | op=r
# MSG recebida | offset=19968 | op=r
# MSG recebida | offset=19969 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19970 | op=r
# MSG recebida | offset=19971 | op=r
# MSG recebida | offset=19972 | op=r
# MSG recebida | offset=19973 | op=r
# MSG recebida | offset=19974 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19975 | op=r
# MSG recebida | offset=19976 | op=r
# MSG recebida | offset=19977 | op=r
# MSG recebida | offset=19978 | op=r
# MSG recebida | offset=19979 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19980 | op=r
# MSG recebida | offset=19981 | op=r
# MSG recebida | offset=19982 | op=r
# MSG recebida | offset=19983 | op=r
# MSG recebida | offset=19984 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19985 | op=r
# MSG recebida | offset=19986 | op=r
# MSG recebida | offset=19987 | op=r
# MSG recebida | offset=19988 | op=r
# MSG recebida | offset=19989 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19990 | op=r
# MSG recebida | offset=19991 | op=r
# MSG recebida | offset=19992 | op=r
# MSG recebida | offset=19993 | op=r
# MSG recebida | offset=19994 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=19995 | op=r
# MSG recebida | offset=19996 | op=r
# MSG recebida | offset=19997 | op=r
# MSG recebida | offset=19998 | op=r
# MSG recebida | offset=19999 | op=r
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=20000 | op=c
# MSG recebida | offset=20001 | op=c
# MSG recebida | offset=20002 | op=c
# MSG recebida | offset=20003 | op=c
# MSG recebida | offset=20004 | op=c
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
# MSG recebida | offset=20005 | op=c
# MSG recebida | offset=20006 | op=c
# MSG recebida | offset=20007 | op=c
# MSG recebida | offset=20008 | op=c
# MSG recebida | offset=20009 | op=c
# [FLUSH] 5 registros → streaming/financeiro/tx_batch_20260613-143041.jsonl
